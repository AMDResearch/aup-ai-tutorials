# %% [markdown]
# # Using MCP Tools with LangChain
#
# In this notebook, we will explore how create a reasoning action agent using tools exposed by a MCP server with LangChain.

# %% [markdown]
# ## Install Dependencies

# %%
# !sudo apt update
# !sudo apt install -y python3-dev graphviz libgraphviz-dev pkg-config

# %%
# !pip install langgraph langchain pygraphviz langchain-openai langchain_mcp_adapters

# %%
# !wget https://raw.githubusercontent.com/AMDResearch/aup-ai-tutorials/refs/heads/ai-agents/ai-agents/math_server.py -O math_server.py

# %% [markdown]
# ## Launch vLLM in the Background
#
# Execute the cell below to create the vllm_serve.sh

# %%
large_model = False
model_name = "Qwen3-30B-A3B" if large_model else "Qwen3-8B"

vllm_file = f"""#!/bin/bash

VLLM_USE_TRITON_FLASH_ATTN=0 \\
vllm serve Qwen/{model_name} \\
    --served-model-name {model_name} \\
    --api-key abc-123 \\
    --port 8000 \\
    --enable-auto-tool-choice \\
    --tool-call-parser hermes \\
    --trust-remote-code 2>&1 | tee vllm_serve.log
"""

with open('vllm_serve.sh', 'w', encoding='utf-8') as f:
    f.write(vllm_file)

# %% [markdown]
# Open a new terminal to execute the `vllm_serve.sh` file. This will serve an LLM locally.
#
# In Jupyter, open a new terminal. `File > New > Terminal`, copy the content below and execute it.
#
# ```sh
# bash vllm_serve.sh
# ```
#
# Now, the LLM will be ready to be used once you see `Application startup complete.`

# %%
from langchain_openai import ChatOpenAI
from langchain_mcp_adapters.tools import load_mcp_tools
from langchain.agents import create_agent
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client

# %% [markdown]
# ## Create Model Object
#
# Use `ChatOpenAI` to connect to the vLLM local endpoint.

# %%
model = ChatOpenAI(
    model=model_name,
    base_url='http://localhost:8000/v1',
    api_key='abc-123')

# %% [markdown]
# ## Launch MCP Server
#
# Using `StdioServerParameters`, we can launch a MCP server in the background that we can communicating using `stdio`. You can check the Python file [math_server.py](math_server.py), this is a very simple Python file that uses `FastMCP` to expose functions as tools.

# %%
server_params = StdioServerParameters(command="python", args=["math_server.py"])

# %% [markdown]
# ## Create stdio Session
#
# Once the MCP server is running, we can start the `stdio_client` session. The cell bellow queries the available MCP tools and displays them.

# %%
async with stdio_client(server_params) as (read, write):
    async with ClientSession(read, write) as session:

        await session.initialize()

        # Convert MCP tools to LangChain tools
        tools = await load_mcp_tools(session)
        print(f"Available tools:")
        for tool in tools:
            print(f'{tool}\n')

# %% [markdown]
# ## Create Async ReAct Agent
#
# We can now create a reasoning and act agent, to do this we are using the `create_agent` available as part of LangGraph. This function takes the model as well as the available tools as parameters. Then we call the agent, that first will reason and if needed will use the available tools.

# %%
async def run_react_agent(query: str):
    async with stdio_client(server_params) as (read, write):
        async with ClientSession(read, write) as session:
            await session.initialize()
            tools = await load_mcp_tools(session)
            agent = create_agent(model, tools)
            agent_response = await agent.ainvoke({"messages": query})
            return agent_response

# %% [markdown]
# Now, we can query the react agent. Note that in the response from the agent the tool square_root is called and the result is used as part of the answer.

# %%
query = "what is the square root of 55?"
agent_response = await run_react_agent(query)
for m in agent_response['messages']:
    m.pretty_print()

# %% [markdown]
# Similarly, if we ask for a multiplication operation, the multiplication tool is called.

# %%
query = "what is the result of 3.14 * 5?"
agent_response = await run_react_agent(query)
for m in agent_response['messages']:
    m.pretty_print()

# %% [markdown]
# Again, the division tools is called.

# %%
query = "what is the result of 99 / 2.3?"
agent_response = await run_react_agent(query)
for m in agent_response['messages']:
    m.pretty_print()

# %% [markdown]
# Note that this agent refuses to answer when we query about a topic that the agent does not find a suitable tool.

# %%
query = "what is the capital of Ireland?"
agent_response = await run_react_agent(query)
for m in agent_response['messages']:
    m.pretty_print()

# %% [markdown]
# ----------
# Copyright (C) 2025 Advanced Micro Devices, Inc. All rights reserved.
#
# SPDX-License-Identifier: MIT
